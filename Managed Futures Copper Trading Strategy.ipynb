# %%
import alphien
import pandas as pd
import numpy as np
# Out:
# Hello Alkanpam, welcome to Alphien!
#
# Importing your Alphien sub-packages into the alphien namespace...
#
# from alphien.data import *
# from alphien.portfolio import *
# from alphien.tutorial import *
#
# Importing your Qlib functions...                                   from team:
# No functions in Qlib teams: COPPER, alkanpam
#
# Alphien environment imported. Let's do some research now!

# %%
dtf = alphien.DataFeatures(tickers=["LP", 'LMCADY Comdty', 'SPX Index', 'USGG10YR Index', 'DXY Curncy'], fields=["bb_live", 'OHLCV', 'OHLC'])
# Out:
# Dropping duplicated field(s): open_price, high_price, low_price, close_price

# %%
copper = dtf.subset(tickers=["LP", 'LMCADY Comdty', 'SPX Index', 'USGG10YR Index', 'DXY Curncy'], fields=["bb_live", 'OHLCV', 'OHLCV', 'OHLC', 'OHLC'])
copper_price = copper.pxs
copper = copper_price.dropna(axis='columns', how ='all')
copper = copper.loc[:,~copper.columns.duplicated()]
# Out:
# Dropping duplicated field(s): open_price, high_price, low_price, close_price, volume, open_price, high_price, low_price, close_price, open_price, high_price, low_price, close_price

# %%
n=10
copper['days_volume_sum'] = np.zeros(shape=(len(copper),1))
for i in range(2, len(copper)):
    copper['days_volume_sum'][i] = copper['LMCADY Comdty.volume'][i-n+1:i+1].sum()
    
copper['days_low_price'] = np.zeros(shape=(len(copper),1))
for i in range(2, len(copper)):
    copper['days_low_price'][i] = copper["LMCADY Comdty.low_price"][i-n+1:i+1].min()

copper['days_high_price'] = np.zeros(shape=(len(copper),1))
for i in range(2, len(copper)):
    copper['days_high_price'][i] = copper["LMCADY Comdty.high_price"][i-n+1:i+1].max()

copper["VWAP_futures"] = ((copper['days_high_price']+copper['days_low_price']+copper["LMCADY Comdty.close_price"])/3) * copper['days_volume_sum']
copper["volume_price"] = copper['LP.bb_live'].pct_change(n)*copper['days_volume_sum']
copper.drop(['days_volume_sum', 'days_low_price','days_high_price'], axis=1, inplace=True)

# %%
def slow_stochastic_oscillator(df, open_price, high_price, low_price, close_price, asset):
    df["14-high"] = df[high_price].rolling(14, min_periods=1).max()
    df["14-low"] = df[low_price].rolling(14, min_periods=1).min()
    df['%K']= (df[close_price] - df['14-low'])*100/(df['14-high'] - df['14-low'])
    df['%D_{}'.format(asset)] = df['%K'].rolling(3, min_periods=1).mean()
    df['%D_3daychange{}'.format(asset)] = df['%D_{}'.format(asset)].pct_change(3)
    df.drop(["14-high", "14-low",'%K'], axis=1, inplace=True)

# %%
slow_stochastic_oscillator(copper, 'LMCADY Comdty.open_price', 'LMCADY Comdty.high_price', 'LMCADY Comdty.low_price', 'LMCADY Comdty.close_price', 'copper')
slow_stochastic_oscillator(copper, 'SPX Index.open_price', 'SPX Index.high_price', 'SPX Index.low_price', 'SPX Index.close_price', 'sp500')
slow_stochastic_oscillator(copper, 'USGG10YR Index.open_price', 'USGG10YR Index.high_price', 'USGG10YR Index.low_price', 'USGG10YR Index.close_price', 'treasury')
slow_stochastic_oscillator(copper, 'DXY Curncy.open_price', 'DXY Curncy.high_price', 'DXY Curncy.low_price', 'DXY Curncy.close_price', 'dxy')

# %%
from scipy.stats import skew 
def skewness(df, price, asset, n=50):
    df['skewness_{}'.format(asset)] = price.pct_change().rolling(window=n).skew()
skewness(copper, copper['LP.bb_live'], 'copper')
skewness(copper, copper['SPX Index.close_price'], 'sp500')
skewness(copper, copper['USGG10YR Index.close_price'], 'treasury')
skewness(copper, copper['DXY Curncy.close_price'], 'dxy')

# %%
def volatility(df, price, asset, n=50):
    df['volatility_{}'.format(asset)] = price.pct_change().rolling(window=n).std()   
volatility(copper, copper['LP.bb_live'], 'copper')
volatility(copper, copper['SPX Index.close_price'], 'sp500')
volatility(copper, copper['USGG10YR Index.close_price'], 'treasury')
volatility(copper, copper['DXY Curncy.close_price'], 'dxy')

# %%
def momentum(returns, price, asset):
    returns['momentum_20_50_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    returns['momentum_8_20_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    for i in range(49, len(price)):
        if price[i-19:i+1].mean() > price[i-49:i+1].mean():
            returns['momentum_20_50_{}'.format(asset)][i] = 1
        if price[i-19:i+1].mean() < price[i-49:i+1].mean():
            returns['momentum_20_50_{}'.format(asset)][i] = 0
        if price[i-7:i+1].mean() > price[i-19:i+1].mean():
            returns['momentum_8_20_{}'.format(asset)][i] = 1
        if price[i-7:i+1].mean() < price[i-19:i+1].mean():
            returns['momentum_8_20_{}'.format(asset)][i] = 0
            
momentum(copper, copper['LP.bb_live'], 'copper')
momentum(copper, copper['SPX Index.close_price'], 'sp500')
momentum(copper, copper['USGG10YR Index.close_price'], 'treasury')
momentum(copper, copper['DXY Curncy.close_price'], 'dxy')

# %%
def top_bottom_distance(returns, price, asset, n=20):
    returns['dist_to_bottom_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    returns['dist_to_top_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    
    for i in range(n, len(price)):
        returns['dist_to_bottom_{}'.format(asset)][i] = (price[i]- price[i-n+1:i+1].min())/price[i]
        returns['dist_to_top_{}'.format(asset)][i] = (price[i-n+1:i+1].max()- price[i])/price[i]
        
top_bottom_distance(copper, copper['LP.bb_live'], 'copper')
top_bottom_distance(copper, copper['SPX Index.close_price'], 'sp500')
top_bottom_distance(copper, copper['USGG10YR Index.close_price'], 'treasury')
top_bottom_distance(copper, copper['DXY Curncy.close_price'], 'dxy')

# %%
def rsi(df, price, asset, n=14):
    deltas = np.diff(price)
    seed = deltas[:n+1]
    up = seed[seed>=0].sum()/n
    down = -seed[seed<0].sum()/n
    rs = up/down
    rsi = np.zeros_like(price)
    rsi[:n] = 100. - 100./(1.+rs)

    for i in range(n, len(price)):
        delta = deltas[i-1] # cause the diff is 1 shorter

        if delta>0:
            upval = delta
            downval = 0.
        else:
            upval = 0.
            downval = -delta

        up = (up*(n-1) + upval)/n
        down = (down*(n-1) + downval)/n
    
        rs = up/down
        rsi[i] = 100. - 100./(1.+rs)
        
    df['rsi_{}'.format(asset)] = rsi
    df['rsi_change_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    df['macd_rsi_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    
    
    df['rsi_change_{}'.format(asset)] = df['rsi_{}'.format(asset)].pct_change(3)

    df['macd_rsi_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    for i in range(25, len(price)):
        if df['rsi_{}'.format(asset)][i-11:i+1].mean() > df['rsi_{}'.format(asset)][i-25:i+1].mean():
            df['macd_rsi_{}'.format(asset)][i] = 1
        if df['rsi_{}'.format(asset)][i-11:i+1].mean() < df['rsi_{}'.format(asset)][i-22:i+1].mean():
            df['macd_rsi_{}'.format(asset)][i] = 0

rsi(copper, copper['LP.bb_live'], 'copper')
rsi(copper, copper['SPX Index.close_price'], 'sp500')
rsi(copper, copper['USGG10YR Index.close_price'], 'treasury')
rsi(copper, copper['DXY Curncy.close_price'], 'dxy')

# %%
def volume_price_actions(df, close, volume, asset, n=10):
    df['{}dayvolume_price_{}'.format(n, asset)] = df[volume].pct_change(n)* df[close].pct_change(n) 
volume_price_actions(copper, 'LMCADY Comdty.close_price', 'LMCADY Comdty.volume', 'copper')
volume_price_actions(copper, 'SPX Index.close_price', 'SPX Index.volume', 'sp500')
volume_price_actions(copper, 'USGG10YR Index.close_price','USGG10YR Index.volume', 'treasury')

# %%
def distance_to_top_and_bottom(copper, price, asset, n=20):
    copper['dist_top_band_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    copper['dist_bottom_band_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    for i in range(n, len(price)):
        std = price[i-n+1:i+1].std()
        mean = price[i-n+1:i+1].mean()
        bollinger_top = mean + 2*std
        bollinger_bottom = mean - 2*std
        copper['dist_top_band_{}'.format(asset)][i] = (bollinger_top - price[i])/price[i]
        copper['dist_bottom_band_{}'.format(asset)][i] = (price[i] - bollinger_bottom)/price[i]
        
distance_to_top_and_bottom(copper, copper['LP.bb_live'], 'copper')
distance_to_top_and_bottom(copper, copper['SPX Index.close_price'], 'sp500')
distance_to_top_and_bottom(copper, copper['USGG10YR Index.close_price'], 'treasury')
distance_to_top_and_bottom(copper, copper['DXY Curncy.close_price'], 'dxy')

# %%
def difference_from_mean(df, price, asset, n=50):
    df['difference_from_mean_{}'.format(asset)] = np.zeros(shape=(len(price),1))
    for i in range(n, len(price)):
        df['difference_from_mean_{}'.format(asset)][i] = (price[i] - price[i-n:i].mean())/price[i-n:i].mean()
difference_from_mean(copper, copper['LP.bb_live'], 'copper')
difference_from_mean(copper, copper['SPX Index.close_price'], 'sp500')
difference_from_mean(copper, copper['USGG10YR Index.close_price'], 'treasury')
difference_from_mean(copper, copper['DXY Curncy.close_price'], 'dxy')

# %%
import numpy.ma as ma
def correlation_tricks(df, price, sp500, treasury, dxy, n=50):
    price_pct_change = price.pct_change()
    sp500_pct_change = sp500.pct_change()
    treasury_pct_change = treasury.pct_change()
    dxy_pct_change = dxy.pct_change()
    
    sp500_pct_change_n = sp500.pct_change(10)
    treasury_pct_change_n = treasury.pct_change(10)
    dxy_pct_change_n = dxy.pct_change(10)
    df['correlation_with_sp500'] = np.zeros(shape=(len(price),1))
    df['correlation_with_treasury'] = np.zeros(shape=(len(price),1))
    df['correlation_with_dxy'] = np.zeros(shape=(len(price),1))
    df['correlation_with_sp500_times_returns'] = np.zeros(shape=(len(price),1))
    df['correlation_with_treasury_times_returns'] = np.zeros(shape=(len(price),1))
    df['correlation_with_dxy_times_returns'] = np.zeros(shape=(len(price),1))
    
    for i in range(n, len(df)):
        df['correlation_with_sp500'][i] = ma.corrcoef(ma.masked_invalid(price_pct_change[i-n+1:i+1]), ma.masked_invalid(sp500_pct_change[i-n+1:i+1]))[0][1]
        df['correlation_with_treasury'][i] = ma.corrcoef(ma.masked_invalid(price_pct_change[i-n+1:i+1]), ma.masked_invalid(treasury_pct_change[i-n+1:i+1]))[0][1]
        df['correlation_with_dxy'][i] = ma.corrcoef(ma.masked_invalid(price_pct_change[i-n+1:i+1]), ma.masked_invalid(dxy_pct_change[i-n+1:i+1]))[0][1]
        
    df['correlation_with_sp500_times_returns'] = df['correlation_with_sp500']*sp500_pct_change_n
    df['correlation_with_treasury_times_returns'] = df['correlation_with_treasury']*treasury_pct_change_n
    df['correlation_with_dxy_times_returns'] = df['correlation_with_dxy']*dxy_pct_change_n

correlation_tricks(copper, copper['LP.bb_live'], copper['SPX Index.close_price'], copper['USGG10YR Index.close_price'], copper['DXY Curncy.close_price'])

# %%
def lagged_returns(df, assets, labels=['copper', 'sp500', 'treasury', 'dxy'], n=[5,10, 20, 50]):
    for i in n:
        for j in range(len(assets)):
            df['lagged{}_{}'.format(i, labels[j])] = assets[j].pct_change(i) 
real_returns = np.zeros(shape=(len(copper),1))
real_returns = copper['LP.bb_live'].pct_change(1)

# %%
lagged_returns(copper, assets=[copper['LP.bb_live'], copper['SPX Index.close_price'], copper['USGG10YR Index.close_price'], copper['DXY Curncy.close_price']], labels=['copper', 'sp500', 'treasury', 'dxy'], n=[5,20])

# %%
n=10
copper['return'] = np.zeros(shape=(len(copper)))
for i in range(len(copper)-n-1):
    copper['return'][i] = (copper['LP.bb_live'][i+n+1]-copper['LP.bb_live'][i+1])/copper['LP.bb_live'][i+1]
    
real_returns = np.zeros(shape=(len(copper),1))
real_returns = copper['LP.bb_live'].pct_change(1)
real_returns = real_returns[50:]

# %%
copper = copper[50:]

# %%
from math import sqrt

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split,cross_val_score,cross_validate
from sklearn.model_selection import TimeSeriesSplit

from sklearn import linear_model
from sklearn.linear_model import Lasso,LassoCV,LassoLarsCV
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import  mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier


import time


random_state = np.random.RandomState(0)

# %%
copper.drop(['LP.bb_live',
'LMCADY Comdty.open_price',
'LMCADY Comdty.high_price',
'LMCADY Comdty.low_price',
'LMCADY Comdty.close_price',
'LMCADY Comdty.volume',
'SPX Index.open_price',
'SPX Index.high_price',
'SPX Index.low_price',
'SPX Index.close_price',
'SPX Index.volume',
'USGG10YR Index.open_price',
'USGG10YR Index.high_price',
'USGG10YR Index.low_price',
'USGG10YR Index.close_price',
'USGG10YR Index.volume',
'DXY Curncy.open_price',
'DXY Curncy.high_price',
'DXY Curncy.low_price',
'DXY Curncy.close_price'], axis=1, inplace=True)

# %%
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [200, 300]
# Number of features to consider at every split
# Maximum number of levels in tree
max_depth = [10, 30, 70, 90]
# Minimum number of samples required to split a node
min_samples_split = [2]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}
pprint(random_grid)
# Out:
# {'max_depth': [10, 30, 70, 90],
#  'min_samples_leaf': [1],
#  'min_samples_split': [2],
#  'n_estimators': [200, 300]}

# %%
n_splits = 5 #Number of train/cv/test folds
pca = PCA()
scaler = StandardScaler()
window_size = 400
change_window_size = 100

max_depth = []
min_samples_leaf = []
min_samples_split = []
n_estimators = []
scores_ = []
correct = 0
total_number = 0
n_ = []
accuracy_ = []
columns_=[0]

true_return=[]

n = 0
last_corrects = 0
last_incorrects = 0

original_signals = np.zeros(shape=(len(copper),1))

while n < len(copper)-window_size:
    print(n)
    scores = []
    coefs = []
    columns = []
    pd.options.mode.use_inf_as_na = True
    copper.iloc[n:n+window_size+1].fillna(copper.iloc[n:n+window_size+1].max(),inplace=True)
    data = pd.DataFrame(scaler.fit_transform(copper.iloc[n:n+window_size+1]), columns =copper.columns)
    pd.options.mode.use_inf_as_na = False
    scaled_data = data.fillna(0)

    #data = data.fillna(0)
    #scaled_data = pd.DataFrame(pca.fit_transform(data.iloc[:,:-1]), columns =copper.columns[:-1])
    #scaled_data['return'] = data.iloc[:,-1]
    
    scaled_data.index = copper[n:n+window_size+1].index
    scaled_data_ = scaled_data.iloc[:,:]
    
    scaled_data = scaled_data.iloc[:-1,]
    scaled_data['return'] = copper.iloc[n:n+window_size,-1]
    y_true = copper.iloc[n+window_size,-1]
    
    trainTestSplit = TimeSeriesSplit(n_splits)

    for trainCvIndices, testIndices in trainTestSplit.split(scaled_data):
        # First, we split Train + CV and Test
        XTrainCv, yTrainCv = scaled_data.iloc[trainCvIndices,:-1], scaled_data.iloc[trainCvIndices,-1]
        XTest, yTest       = scaled_data.iloc[testIndices,:-1]   , scaled_data.iloc[testIndices,-1]
    
        # Then, we build a list of the form [ ( [...Train Indices...], [...CV Indices...]  )]
        testLength = len(XTest)
        trainCvSplit = [(list(range(trainCvIndices[0],trainCvIndices[-testLength])),
                     list(range(trainCvIndices[-testLength],trainCvIndices[-1]+1)))]
        
    modelCV = LassoCV(fit_intercept = False, max_iter = 100000, tol = 0.0001, cv = trainTestSplit).fit(XTrainCv,yTrainCv)
    coefs.append(modelCV.coef_)
        
    columns = []

    for i in range(len(coefs[0])):
        if coefs[0][i] != 0:
            columns.append(scaled_data.columns[i])
        if i == len(coefs[0])-1:
            columns.append('return')
    n +=1
    print('col', len(columns)-1)
    if len(columns) < 2:
        continue
        
    if (len(columns) ==2) and columns == columns_[-1]:
        continue
        
    columns_.append(columns)
        
    # RANDOM FOREST REGRESSOR

    scaled_data = scaled_data[columns]
    for i in range(len(scaled_data['return'])):
        if scaled_data['return'][i] > 0.0:
            scaled_data['return'][i] = 1
        #elif scaled_data['return'][i] < -0.01:
        #    scaled_data['return'][i] = -1
        else:
            scaled_data['return'][i] = -1
    
    train_MSE = []
    best_p = []
    
    n_splits = 5
    trainTestSplit = TimeSeriesSplit(n_splits)

    
    for trainCvIndices, testIndices in trainTestSplit.split(scaled_data):
        XTrainCv, yTrainCv = scaled_data.iloc[trainCvIndices,:-1], scaled_data.iloc[trainCvIndices,-1]
        XTest, yTest       = scaled_data.iloc[testIndices,:-1]   , scaled_data.iloc[testIndices,-1]
    
        # Then, we build a list of the form [ ( [...Train Indices...], [...CV Indices...]  )]
        testLength = len(XTest)
        trainCvSplit = [(list(range(trainCvIndices[0],trainCvIndices[-testLength])),
                     list(range(trainCvIndices[-testLength],trainCvIndices[-1]+1)))]
        
    rf = RandomForestClassifier(class_weight='balanced', random_state=random_state)
    rf_random = GridSearchCV(estimator = rf, param_grid = random_grid, cv = trainTestSplit)
    rf_random.fit(scaled_data.iloc[:,:-1],scaled_data.iloc[:,-1])
    #XTest = XTest[:5]
    #yTest = yTest[:5]
    #y_pred = rf_random.predict(XTest)
    #scores_.append(rf_random.score(XTest, yTest))
    #best_p.append(rf_random.best_params_)
           
    
    max_depth.append(rf_random.best_params_['max_depth'])
    min_samples_leaf.append(rf_random.best_params_['min_samples_leaf'])
    min_samples_split.append(rf_random.best_params_['min_samples_split'])
    n_estimators.append(rf_random.best_params_['n_estimators'])
                         

    final_regression = RandomForestClassifier(class_weight='balanced', random_state=random_state, n_estimators=rf_random.best_params_['max_depth'], max_depth=rf_random.best_params_['min_samples_leaf'], min_samples_split=rf_random.best_params_['min_samples_split'], min_samples_leaf = rf_random.best_params_['n_estimators']) 
    final_regression.fit(scaled_data.iloc[:,:-1], scaled_data.iloc[:,-1])
    
    
    x_true = pd.DataFrame()
    for i in range(len(columns[:-1])):
        x_true[columns[i]] = [scaled_data_.iloc[-1,:-1][columns[:-1]][i]]
    final_y_pred = final_regression.predict(x_true)
    #print('y_true', y_true)
    #print('y_pred', final_y_pred)
    
    if (final_y_pred == 1 and y_true > 0.0) or (final_y_pred == -1 and y_true < -0.0) or ((final_y_pred == 0 and y_true < 0.0) and (final_y_pred == 0 and y_true > -0.0)) :
        print('Correct!!! ...', 'prediction: ', final_y_pred, 'true return: ', y_true)
        true_return.append(round(abs(y_true),5))
        correct += 1
        accuracy_.append(1)
        last_incorrects = 0
        
        if window_size == change_window_size:
            last_corrects += 1
        
    else:
        print('Not Correct:( ...', 'prediction: ', final_y_pred, 'true return: ', y_true)
        true_return.append(-round(abs(y_true),5))
        accuracy_.append(0)
        last_corrects = 0
        last_incorrects +=1
                         
    if (last_corrects > 0 and last_incorrects <= 2) or (last_corrects = 0 and last_incorrects >= 3):
        window_size = change_window_size
    else:
        window_size = 400
        
    print('n: ', n)
    print('what are they?', scaled_data[columns].columns[:-1])
    n_.append(n)
    total_number += 1
    original_signals[n+window_size] = final_y_pred
    
    n += 10
# Out:
# 0
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.046828724443912506
# n:  1
# what are they? Index(['momentum_20_50_sp500', 'momentum_20_50_dxy'], dtype='object')
# 11
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.10797124356031418
# n:  12
# what are they? Index(['momentum_20_50_dxy'], dtype='object')
# 22
# col 0
# 23
# col 0
# 24
# col 0
# 25
# col 0
# 26
# col 0
# 27
# col 0
# 28
# col 1
# 29
# col 0
# 30
# col 1
# 31
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.04980206489562988
# n:  32
# what are they? Index(['correlation_with_treasury'], dtype='object')
# 42
# col 2
# Not Correct:( ... prediction:  [1.] true return:  -0.01082372572273016
# n:  43
# what are they? Index(['momentum_20_50_dxy', 'correlation_with_treasury'], dtype='object')
# 53
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.05384708568453789
# n:  54
# what are they? Index(['correlation_with_treasury'], dtype='object')
# 64
# col 0
# 65
# col 0
# 66
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.03389448672533035
# n:  67
# what are they? Index(['volatility_copper'], dtype='object')
# 77
# col 1
# 78
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.016677958890795708
# n:  79
# what are they? Index(['correlation_with_treasury'], dtype='object')
# 89
# col 1
# 90
# col 1
# 91
# col 0
# 92
# col 0
# 93
# col 1
# 94
# col 1
# 95
# col 1
# 96
# col 0
# 97
# col 1
# 98
# col 1
# 99
# col 0
# 100
# col 1
# 101
# col 1
# 102
# col 0
# 103
# col 0
# 104
# col 1
# 105
# col 1
# 106
# col 1
# 107
# col 1
# 108
# col 0
# 109
# col 1
# 110
# col 1
# 111
# col 1
# 112
# col 0
# 113
# col 1
# 114
# col 0
# 115
# col 1
# 116
# col 1
# 117
# col 0
# 118
# col 0
# 119
# col 0
# 120
# col 0
# 121
# col 0
# 122
# col 1
# 123
# col 1
# 124
# col 1
# 125
# col 0
# 126
# col 1
# 127
# col 1
# 128
# col 0
# 129
# col 0
# 130
# col 0
# 131
# col 0
# 132
# col 0
# 133
# col 0
# 134
# col 1
# 135
# col 1
# 136
# col 1
# 137
# col 1
# 138
# col 1
# 139
# col 1
# 140
# col 1
# 141
# col 0
# 142
# col 0
# 143
# col 0
# 144
# col 0
# 145
# col 0
# 146
# col 1
# 147
# col 1
# 148
# col 1
# 149
# col 0
# 150
# col 0
# 151
# col 1
# 152
# col 0
# 153
# col 0
# 154
# col 0
# 155
# col 0
# 156
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.06141754984855652
# n:  157
# what are they? Index(['momentum_20_50_sp500'], dtype='object')
# 167
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.046407535672187805
# n:  168
# what are they? Index(['dist_bottom_band_treasury'], dtype='object')
# 178
# col 1
# 179
# col 1
# 180
# col 1
# 181
# col 0
# 182
# col 0
# 183
# col 1
# 184
# col 1
# 185
# col 0
# 186
# col 0
# 187
# col 0
# 188
# col 0
# 189
# col 0
# 190
# col 1
# 191
# col 0
# 192
# col 1
# 193
# col 0
# 194
# col 1
# 195
# col 1
# 196
# col 0
# 197
# col 0
# 198
# col 0
# 199
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.001033635693602264
# n:  200
# what are they? Index(['volatility_sp500'], dtype='object')
# 210
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.06545272469520569
# n:  211
# what are they? Index(['dist_bottom_band_treasury'], dtype='object')
# 221
# col 0
# 222
# col 1
# 223
# col 1
# 224
# col 1
# 225
# col 0
# 226
# col 1
# 227
# col 0
# 228
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.044394657015800476
# n:  229
# what are they? Index(['dist_to_top_copper'], dtype='object')
# 239
# col 0
# 240
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.010916621424257755
# n:  241
# what are they? Index(['dist_to_bottom_copper', 'dist_to_top_copper',
#        'dist_bottom_band_treasury'],
#       dtype='object')
# 251
# col 6
# Not Correct:( ... prediction:  [-1.] true return:  0.05812126025557518
# n:  252
# what are they? Index(['volatility_treasury', 'dist_to_bottom_copper', 'dist_to_top_copper',
#        'rsi_copper', 'dist_bottom_band_treasury', 'lagged20_copper'],
#       dtype='object')
# 262
# col 4
# Not Correct:( ... prediction:  [-1.] true return:  0.047505933791399
# n:  263
# what are they? Index(['volatility_treasury', 'dist_bottom_band_treasury',
#        'difference_from_mean_copper', 'lagged20_copper'],
#       dtype='object')
# 273
# col 10
# Not Correct:( ... prediction:  [-1.] true return:  0.0019884463399648666
# n:  274
# what are they? Index(['volatility_treasury', 'momentum_20_50_copper', 'momentum_8_20_sp500',
#        'momentum_20_50_treasury', 'dist_to_bottom_copper',
#        'dist_to_top_copper', 'dist_bottom_band_treasury',
#        'difference_from_mean_copper', 'correlation_with_dxy_times_returns',
#        'lagged20_copper'],
#       dtype='object')
# 284
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.015985064208507538
# n:  285
# what are they? Index(['dist_to_bottom_copper'], dtype='object')
# 295
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.05180492624640465
# n:  296
# what are they? Index(['dist_to_bottom_copper', 'lagged20_copper'], dtype='object')
# 306
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.058651894330978394
# n:  307
# what are they? Index(['lagged20_copper'], dtype='object')
# 317
# col 20
# Correct!!! ... prediction:  [1.] true return:  0.025307994335889816
# n:  318
# what are they? Index(['volume_price', '%D_3daychangecopper', '%D_3daychangesp500',
#        'skewness_copper', 'volatility_sp500', 'momentum_20_50_copper',
#        'momentum_20_50_sp500', 'momentum_8_20_sp500',
#        'momentum_20_50_treasury', 'dist_to_bottom_copper',
#        'dist_to_top_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_treasury', 'correlation_with_sp500',
#        'correlation_with_dxy', 'correlation_with_treasury_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged5_treasury',
#        'lagged20_copper', 'lagged20_sp500'],
#       dtype='object')
# 328
# col 22
# Correct!!! ... prediction:  [1.] true return:  0.031162114813923836
# n:  329
# what are they? Index(['VWAP_futures', 'volume_price', '%D_3daychangecopper',
#        '%D_3daychangesp500', 'skewness_sp500', 'skewness_treasury',
#        'skewness_dxy', 'volatility_sp500', 'momentum_20_50_copper',
#        'momentum_8_20_copper', 'momentum_20_50_sp500', 'momentum_8_20_sp500',
#        'momentum_20_50_treasury', 'dist_to_bottom_copper',
#        'dist_top_band_sp500', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'correlation_with_sp500_times_returns',
#        'correlation_with_treasury_times_returns', 'lagged20_copper',
#        'lagged20_sp500'],
#       dtype='object')
# 339
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.049240950495004654
# n:  340
# what are they? Index(['difference_from_mean_copper'], dtype='object')
# 350
# col 0
# 351
# col 0
# 352
# col 1
# 353
# col 1
# 354
# col 1
# 355
# col 1
# 356
# col 1
# 357
# col 0
# 358
# col 1
# 359
# col 0
# 360
# col 1
# 361
# col 1
# 362
# col 0
# 363
# col 0
# 364
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.021792348474264145
# n:  365
# what are they? Index(['lagged20_copper'], dtype='object')
# 375
# col 0
# 376
# col 0
# 377
# col 1
# 378
# col 1
# 379
# col 0
# 380
# col 0
# 381
# col 1
# 382
# col 0
# 383
# col 0
# 384
# col 0
# 385
# col 1
# 386
# col 0
# 387
# col 0
# 388
# col 0
# 389
# col 0
# 390
# col 0
# 391
# col 1
# 392
# col 1
# 393
# col 1
# 394
# col 1
# 395
# col 0
# 396
# col 0
# 397
# col 0
# 398
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.17056512832641602
# n:  399
# what are they? Index(['dist_to_bottom_copper'], dtype='object')
# 409
# col 0
# 410
# col 0
# 411
# col 0
# 412
# col 0
# 413
# col 0
# 414
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.10912270098924637
# n:  415
# what are they? Index(['momentum_20_50_treasury'], dtype='object')
# 425
# col 0
# 426
# col 0
# 427
# col 0
# 428
# col 0
# 429
# col 0
# 430
# col 0
# 431
# col 0
# 432
# col 0
# 433
# col 1
# 434
# col 0
# 435
# col 0
# 436
# col 0
# 437
# col 0
# 438
# col 10
# Not Correct:( ... prediction:  [1.] true return:  -0.1722223162651062
# n:  439
# what are they? Index(['momentum_20_50_copper', 'momentum_8_20_sp500',
#        'momentum_20_50_treasury', 'dist_to_bottom_copper', 'macd_rsi_treasury',
#        'dist_bottom_band_dxy', 'difference_from_mean_dxy',
#        'correlation_with_treasury', 'correlation_with_dxy', 'lagged20_sp500'],
#       dtype='object')
# 449
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.04566008225083351
# n:  450
# what are they? Index(['lagged20_sp500'], dtype='object')
# 460
# col 2
# Not Correct:( ... prediction:  [-1.] true return:  0.08826390653848648
# n:  461
# what are they? Index(['difference_from_mean_dxy', 'lagged20_sp500'], dtype='object')
# 471
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.04947025701403618
# n:  472
# what are they? Index(['lagged20_sp500'], dtype='object')
# 482
# col 0
# 483
# col 0
# 484
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.01626550778746605
# n:  485
# what are they? Index(['volatility_dxy'], dtype='object')
# 495
# col 0
# 496
# col 0
# 497
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.002233873587101698
# n:  498
# what are they? Index(['skewness_treasury'], dtype='object')
# 508
# col 9
# Correct!!! ... prediction:  [-1.] true return:  -0.0522390753030777
# n:  509
# what are they? Index(['skewness_treasury', 'volatility_copper', 'volatility_sp500',
#        'volatility_dxy', 'dist_to_top_sp500', 'dist_to_bottom_treasury',
#        'dist_bottom_band_treasury', 'difference_from_mean_treasury',
#        'lagged20_sp500'],
#       dtype='object')
# 519
# col 62
# Correct!!! ... prediction:  [-1.] true return:  -0.05490628257393837
# n:  520
# what are they? Index(['VWAP_futures', 'volume_price', '%D_copper', '%D_3daychangecopper',
#        '%D_sp500', '%D_3daychangesp500', '%D_3daychangetreasury', '%D_dxy',
#        '%D_3daychangedxy', 'skewness_copper', 'skewness_sp500',
#        'skewness_treasury', 'skewness_dxy', 'volatility_copper',
#        'volatility_sp500', 'volatility_treasury', 'volatility_dxy',
#        'momentum_20_50_copper', 'momentum_8_20_copper', 'momentum_20_50_sp500',
#        'momentum_8_20_sp500', 'momentum_20_50_treasury',
#        'momentum_8_20_treasury', 'momentum_20_50_dxy', 'dist_to_bottom_copper',
#        'dist_to_bottom_sp500', 'dist_to_top_sp500', 'dist_to_bottom_treasury',
#        'dist_to_top_treasury', 'dist_to_bottom_dxy', 'dist_to_top_dxy',
#        'rsi_copper', 'rsi_change_copper', 'rsi_treasury',
#        'rsi_change_treasury', '10dayvolume_price_copper',
#        '10dayvolume_price_sp500', 'dist_top_band_copper',
#        'dist_bottom_band_copper', 'dist_bottom_band_sp500',
#        'dist_top_band_treasury', 'dist_bottom_band_treasury',
#        'dist_top_band_dxy', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_treasury', 'difference_from_mean_dxy',
#        'correlation_with_sp500', 'correlation_with_treasury',
#        'correlation_with_dxy', 'correlation_with_sp500_times_returns',
#        'correlation_with_treasury_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged5_copper', 'lagged5_sp500',
#        'lagged5_treasury', 'lagged5_dxy', 'lagged20_copper', 'lagged20_sp500',
#        'lagged20_treasury', 'lagged20_dxy'],
#       dtype='object')
# 530
# col 3
# Correct!!! ... prediction:  [1.] true return:  0.05088835582137108
# n:  531
# what are they? Index(['%D_treasury', 'dist_to_top_sp500', 'dist_bottom_band_treasury'], dtype='object')
# 541
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.031913623213768005
# n:  542
# what are they? Index(['dist_bottom_band_treasury'], dtype='object')
# 552
# col 1
# 553
# col 1
# 554
# col 1
# 555
# col 0
# 556
# col 0
# 557
# col 1
# 558
# col 0
# 559
# col 1
# 560
# col 0
# 561
# col 0
# 562
# col 1
# 563
# col 0
# 564
# col 1
# 565
# col 1
# 566
# col 0
# 567
# col 0
# 568
# col 1
# 569
# col 0
# 570
# col 0
# 571
# col 0
# 572
# col 0
# 573
# col 0
# 574
# col 0
# 575
# col 0
# 576
# col 0
# 577
# col 0
# 578
# col 0
# 579
# col 3
# Correct!!! ... prediction:  [-1.] true return:  -0.05003669112920761
# n:  580
# what are they? Index(['%D_treasury', 'dist_bottom_band_treasury',
#        'difference_from_mean_treasury'],
#       dtype='object')
# 590
# col 2
# Correct!!! ... prediction:  [-1.] true return:  -0.07525845617055893
# n:  591
# what are they? Index(['dist_bottom_band_treasury', 'difference_from_mean_treasury'], dtype='object')
# 601
# col 0
# 602
# col 0
# 603
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.014529451727867126
# n:  604
# what are they? Index(['dist_bottom_band_treasury'], dtype='object')
# 614
# col 0
# 615
# col 0
# 616
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.086833655834198
# n:  617
# what are they? Index(['difference_from_mean_treasury'], dtype='object')
# 627
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.014603125862777233
# n:  628
# what are they? Index(['dist_bottom_band_treasury'], dtype='object')
# 638
# col 4
# Correct!!! ... prediction:  [1.] true return:  0.11101792007684708
# n:  639
# what are they? Index(['skewness_treasury', 'momentum_20_50_copper',
#        'dist_bottom_band_treasury', 'difference_from_mean_treasury'],
#       dtype='object')
# 649
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.1246396154165268
# n:  650
# what are they? Index(['difference_from_mean_treasury'], dtype='object')
# 660
# col 0
# 661
# col 0
# 662
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.09192287176847458
# n:  663
# what are they? Index(['skewness_treasury'], dtype='object')
# 673
# col 1
# 674
# col 1
# 675
# col 0
# 676
# col 0
# 677
# col 0
# 678
# col 0
# 679
# col 0
# 680
# col 0
# 681
# col 0
# 682
# col 0
# 683
# col 0
# 684
# col 26
# Correct!!! ... prediction:  [-1.] true return:  -0.10400805622339249
# n:  685
# what are they? Index(['VWAP_futures', '%D_dxy', 'skewness_copper', 'skewness_sp500',
#        'skewness_treasury', 'volatility_copper', 'volatility_treasury',
#        'momentum_20_50_copper', 'momentum_20_50_sp500', 'momentum_20_50_dxy',
#        'dist_to_top_copper', 'macd_rsi_copper', '10dayvolume_price_copper',
#        'dist_top_band_copper', 'dist_bottom_band_copper',
#        'dist_top_band_sp500', 'dist_bottom_band_treasury', 'dist_top_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_treasury',
#        'difference_from_mean_dxy', 'correlation_with_sp500',
#        'correlation_with_dxy', 'correlation_with_treasury_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged5_treasury'],
#       dtype='object')
# 695
# col 0
# 696
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.0059137470088899136
# n:  697
# what are they? Index(['difference_from_mean_treasury'], dtype='object')
# 707
# col 0
# 708
# col 0
# 709
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.012347148731350899
# n:  710
# what are they? Index(['skewness_treasury'], dtype='object')
# 720
# col 0
# 721
# col 0
# 722
# col 0
# 723
# col 1
# 724
# col 0
# 725
# col 1
# 726
# col 0
# 727
# col 0
# 728
# col 1
# 729
# col 1
# 730
# col 1
# 731
# col 0
# 732
# col 1
# 733
# col 1
# 734
# col 1
# 735
# col 0
# 736
# col 0
# 737
# col 6
# Not Correct:( ... prediction:  [1.] true return:  -0.03881014883518219
# n:  738
# what are they? Index(['%D_treasury', 'skewness_treasury', 'momentum_20_50_copper',
#        'momentum_8_20_dxy', 'macd_rsi_copper',
#        'difference_from_mean_treasury'],
#       dtype='object')
# 748
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.10060728341341019
# n:  749
# what are they? Index(['skewness_treasury'], dtype='object')
# 759
# col 0
# 760
# col 1
# 761
# col 0
# 762
# col 0
# 763
# col 0
# 764
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.008493650704622269
# n:  765
# what are they? Index(['skewness_treasury', 'macd_rsi_copper', 'dist_bottom_band_treasury'], dtype='object')
# 775
# col 0
# 776
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.06387627869844437
# n:  777
# what are they? Index(['skewness_treasury'], dtype='object')
# 787
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.005539393983781338
# n:  788
# what are they? Index(['macd_rsi_copper'], dtype='object')
# 798
# col 1
# 799
# col 1
# 800
# col 1
# 801
# col 0
# 802
# col 0
# 803
# col 1
# 804
# col 0
# 805
# col 1
# 806
# col 0
# 807
# col 0
# 808
# col 0
# 809
# col 1
# 810
# col 0
# 811
# col 0
# 812
# col 0
# 813
# col 0
# 814
# col 0
# 815
# col 1
# 816
# col 0
# 817
# col 1
# 818
# col 1
# 819
# col 0
# 820
# col 1
# 821
# col 0
# 822
# col 0
# 823
# col 1
# 824
# col 0
# 825
# col 0
# 826
# col 0
# 827
# col 0
# 828
# col 0
# 829
# col 1
# 830
# col 0
# 831
# col 0
# 832
# col 0
# 833
# col 1
# 834
# col 1
# 835
# col 1
# 836
# col 0
# 837
# col 0
# 838
# col 1
# 839
# col 0
# 840
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.05643417313694954
# n:  841
# what are they? Index(['momentum_20_50_sp500'], dtype='object')
# 851
# col 1
# 852
# col 1
# 853
# col 0
# 854
# col 0
# 855
# col 1
# 856
# col 0
# 857
# col 1
# 858
# col 1
# 859
# col 1
# 860
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.020388301461935043
# n:  861
# what are they? Index(['macd_rsi_copper'], dtype='object')
# 871
# col 30
# Not Correct:( ... prediction:  [-1.] true return:  0.09926256537437439
# n:  872
# what are they? Index(['VWAP_futures', '%D_sp500', '%D_3daychangesp500', '%D_treasury',
#        '%D_3daychangetreasury', '%D_dxy', 'skewness_sp500',
#        'skewness_treasury', 'skewness_dxy', 'volatility_copper',
#        'volatility_sp500', 'volatility_dxy', 'momentum_20_50_copper',
#        'momentum_20_50_sp500', 'momentum_20_50_treasury', 'momentum_8_20_dxy',
#        'rsi_change_copper', 'macd_rsi_copper', 'dist_top_band_copper',
#        'dist_top_band_dxy', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_dxy', 'correlation_with_treasury',
#        'correlation_with_sp500_times_returns',
#        'correlation_with_treasury_times_returns', 'lagged5_copper',
#        'lagged5_dxy', 'lagged20_sp500'],
#       dtype='object')
# 882
# col 35
# Not Correct:( ... prediction:  [-1.] true return:  0.056352648884058
# n:  883
# what are they? Index(['VWAP_futures', '%D_sp500', '%D_treasury', '%D_3daychangetreasury',
#        '%D_dxy', 'skewness_copper', 'skewness_sp500', 'skewness_treasury',
#        'skewness_dxy', 'volatility_copper', 'volatility_sp500',
#        'volatility_treasury', 'volatility_dxy', 'momentum_8_20_copper',
#        'momentum_20_50_sp500', 'momentum_20_50_treasury', 'momentum_20_50_dxy',
#        'momentum_8_20_dxy', 'dist_to_bottom_sp500', 'rsi_change_copper',
#        'macd_rsi_copper', '10dayvolume_price_copper', 'dist_top_band_copper',
#        'dist_bottom_band_copper', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_treasury',
#        'difference_from_mean_dxy', 'correlation_with_treasury',
#        'correlation_with_treasury_times_returns', 'lagged5_copper',
#        'lagged5_sp500', 'lagged5_dxy', 'lagged20_copper', 'lagged20_sp500'],
#       dtype='object')
# 893
# col 34
# Not Correct:( ... prediction:  [-1.] true return:  0.0016550548607483506
# n:  894
# what are they? Index(['VWAP_futures', '%D_sp500', '%D_treasury', '%D_3daychangetreasury',
#        '%D_dxy', 'skewness_copper', 'skewness_sp500', 'skewness_treasury',
#        'skewness_dxy', 'volatility_copper', 'volatility_sp500',
#        'volatility_dxy', 'momentum_20_50_sp500', 'momentum_20_50_treasury',
#        'momentum_20_50_dxy', 'momentum_8_20_dxy', 'rsi_change_copper',
#        'macd_rsi_copper', '10dayvolume_price_copper', 'dist_top_band_copper',
#        'dist_bottom_band_copper', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_dxy', 'correlation_with_dxy',
#        'correlation_with_sp500_times_returns',
#        'correlation_with_treasury_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged5_copper', 'lagged5_sp500',
#        'lagged5_dxy', 'lagged20_copper', 'lagged20_sp500'],
#       dtype='object')
# 904
# col 28
# Correct!!! ... prediction:  [-1.] true return:  -0.0233601164072752
# n:  905
# what are they? Index(['VWAP_futures', '%D_treasury', '%D_3daychangetreasury', '%D_dxy',
#        'skewness_copper', 'skewness_sp500', 'skewness_treasury',
#        'volatility_copper', 'volatility_sp500', 'volatility_dxy',
#        'momentum_20_50_sp500', 'momentum_20_50_treasury', 'momentum_20_50_dxy',
#        'momentum_8_20_dxy', 'rsi_change_copper', 'macd_rsi_copper',
#        'dist_top_band_copper', 'dist_bottom_band_copper',
#        'dist_bottom_band_dxy', 'difference_from_mean_copper',
#        'difference_from_mean_sp500', 'difference_from_mean_dxy',
#        'correlation_with_dxy', 'correlation_with_treasury_times_returns',
#        'lagged5_copper', 'lagged5_sp500', 'lagged5_dxy', 'lagged20_sp500'],
#       dtype='object')
# 915
# col 22
# Not Correct:( ... prediction:  [-1.] true return:  0.01619206741452217
# n:  916
# what are they? Index(['VWAP_futures', '%D_treasury', '%D_dxy', 'skewness_sp500',
#        'skewness_treasury', 'volatility_copper', 'volatility_sp500',
#        'volatility_dxy', 'momentum_20_50_sp500', 'momentum_20_50_dxy',
#        'momentum_8_20_dxy', 'macd_rsi_copper', 'dist_top_band_copper',
#        'dist_bottom_band_dxy', 'difference_from_mean_copper',
#        'difference_from_mean_sp500', 'difference_from_mean_dxy',
#        'correlation_with_dxy', 'correlation_with_treasury_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged5_copper',
#        'lagged5_sp500'],
#       dtype='object')
# 926
# col 29
# Not Correct:( ... prediction:  [1.] true return:  -0.006737376097589731
# n:  927
# what are they? Index(['VWAP_futures', '%D_dxy', 'skewness_sp500', 'skewness_treasury',
#        'skewness_dxy', 'volatility_copper', 'volatility_sp500',
#        'volatility_dxy', 'momentum_8_20_copper', 'momentum_20_50_sp500',
#        'momentum_20_50_treasury', 'momentum_8_20_treasury',
#        'momentum_8_20_dxy', 'rsi_change_copper', 'macd_rsi_copper',
#        '10dayvolume_price_copper', '10dayvolume_price_sp500',
#        'dist_top_band_copper', 'dist_top_band_treasury', 'dist_top_band_dxy',
#        'dist_bottom_band_dxy', 'difference_from_mean_copper',
#        'difference_from_mean_sp500', 'difference_from_mean_dxy',
#        'correlation_with_dxy', 'correlation_with_treasury_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged5_copper',
#        'lagged5_sp500'],
#       dtype='object')
# 937
# col 18
# Not Correct:( ... prediction:  [1.] true return:  -0.044405821710824966
# n:  938
# what are they? Index(['VWAP_futures', '%D_dxy', 'skewness_sp500', 'skewness_dxy',
#        'volatility_copper', 'volatility_dxy', 'momentum_20_50_sp500',
#        'macd_rsi_copper', '10dayvolume_price_sp500', 'dist_top_band_copper',
#        'dist_top_band_treasury', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_dxy', 'correlation_with_dxy',
#        'correlation_with_dxy_times_returns', 'lagged5_copper'],
#       dtype='object')
# 948
# col 11
# Correct!!! ... prediction:  [-1.] true return:  -0.002533812541514635
# n:  949
# what are they? Index(['VWAP_futures', '%D_dxy', 'volatility_copper', 'momentum_20_50_sp500',
#        'macd_rsi_copper', '10dayvolume_price_sp500', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_dxy', 'lagged5_copper'],
#       dtype='object')
# 959
# col 13
# Correct!!! ... prediction:  [-1.] true return:  -0.020327040925621986
# n:  960
# what are they? Index(['VWAP_futures', '%D_dxy', 'skewness_treasury', 'volatility_copper',
#        'momentum_20_50_sp500', 'momentum_8_20_treasury', 'macd_rsi_copper',
#        '10dayvolume_price_sp500', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_dxy', 'lagged5_copper'],
#       dtype='object')
# 970
# col 20
# Not Correct:( ... prediction:  [-1.] true return:  0.08030088245868683
# n:  971
# what are they? Index(['VWAP_futures', '%D_dxy', 'skewness_treasury', 'volatility_copper',
#        'volatility_dxy', 'momentum_20_50_sp500', 'momentum_8_20_treasury',
#        'dist_to_top_sp500', 'macd_rsi_copper', '10dayvolume_price_sp500',
#        'dist_bottom_band_sp500', 'dist_top_band_treasury', 'dist_top_band_dxy',
#        'dist_bottom_band_dxy', 'difference_from_mean_copper',
#        'difference_from_mean_sp500', 'difference_from_mean_dxy',
#        'correlation_with_dxy_times_returns', 'lagged5_copper',
#        'lagged20_sp500'],
#       dtype='object')
# 981
# col 12
# Correct!!! ... prediction:  [-1.] true return:  -0.02784641459584236
# n:  982
# what are they? Index(['VWAP_futures', '%D_dxy', 'volatility_copper', 'momentum_20_50_sp500',
#        'momentum_20_50_dxy', 'macd_rsi_copper', '10dayvolume_price_sp500',
#        'dist_top_band_dxy', 'difference_from_mean_copper',
#        'difference_from_mean_sp500', 'difference_from_mean_dxy',
#        'lagged5_copper'],
#       dtype='object')
# 992
# col 10
# Correct!!! ... prediction:  [-1.] true return:  -0.029793301597237587
# n:  993
# what are they? Index(['%D_dxy', 'volatility_copper', 'momentum_20_50_sp500',
#        'momentum_20_50_treasury', 'macd_rsi_copper', '10dayvolume_price_sp500',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_dxy', 'lagged5_copper'],
#       dtype='object')
# 1003
# col 2
# Not Correct:( ... prediction:  [1.] true return:  -0.10410556197166443
# n:  1004
# what are they? Index(['volatility_copper', 'momentum_20_50_sp500'], dtype='object')
# 1014
# col 6
# Correct!!! ... prediction:  [1.] true return:  0.03545820713043213
# n:  1015
# what are they? Index(['volatility_copper', 'momentum_20_50_sp500', 'macd_rsi_copper',
#        '10dayvolume_price_sp500', 'difference_from_mean_copper',
#        'difference_from_mean_dxy'],
#       dtype='object')
# 1025
# col 3
# Correct!!! ... prediction:  [-1.] true return:  -0.07917856425046921
# n:  1026
# what are they? Index(['volatility_copper', 'momentum_20_50_sp500', 'macd_rsi_copper'], dtype='object')
# 1036
# col 14
# Correct!!! ... prediction:  [-1.] true return:  -0.04804150015115738
# n:  1037
# what are they? Index(['VWAP_futures', '%D_treasury', 'skewness_sp500', 'skewness_treasury',
#        'volatility_copper', 'momentum_20_50_copper', 'momentum_20_50_sp500',
#        'momentum_20_50_dxy', 'macd_rsi_copper', '10dayvolume_price_sp500',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'correlation_with_sp500', 'lagged20_sp500'],
#       dtype='object')
# 1047
# col 6
# Correct!!! ... prediction:  [-1.] true return:  -0.20568250119686127
# n:  1048
# what are they? Index(['%D_treasury', 'volatility_copper', 'momentum_20_50_copper',
#        'momentum_20_50_sp500', 'momentum_20_50_dxy', 'macd_rsi_copper'],
#       dtype='object')
# 1058
# col 12
# Correct!!! ... prediction:  [-1.] true return:  -0.22119583189487457
# n:  1059
# what are they? Index(['VWAP_futures', '%D_treasury', 'volatility_copper',
#        'momentum_20_50_copper', 'momentum_20_50_sp500', 'momentum_20_50_dxy',
#        'momentum_8_20_dxy', 'dist_to_bottom_treasury', 'macd_rsi_copper',
#        '10dayvolume_price_sp500', 'difference_from_mean_copper',
#        'correlation_with_treasury'],
#       dtype='object')
# 1069
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.22592414915561676
# n:  1070
# what are they? Index(['momentum_20_50_sp500'], dtype='object')
# 1080
# col 0
# 1081
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.05178562179207802
# n:  1082
# what are they? Index(['momentum_20_50_copper'], dtype='object')
# 1092
# col 0
# 1093
# col 0
# 1094
# col 0
# 1095
# col 0
# 1096
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.04059604927897453
# n:  1097
# what are they? Index(['momentum_20_50_sp500'], dtype='object')
# 1107
# col 0
# 1108
# col 1
# 1109
# col 1
# 1110
# col 0
# 1111
# col 0
# 1112
# col 0
# 1113
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.15387876331806183
# n:  1114
# what are they? Index(['skewness_dxy'], dtype='object')
# 1124
# col 0
# 1125
# col 1
# 1126
# col 1
# 1127
# col 0
# 1128
# col 0
# 1129
# col 0
# 1130
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.07646773755550385
# n:  1131
# what are they? Index(['correlation_with_sp500_times_returns'], dtype='object')
# 1141
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.11252367496490479
# n:  1142
# what are they? Index(['dist_top_band_copper'], dtype='object')
# 1152
# col 1
# 1153
# col 1
# 1154
# col 3
# Correct!!! ... prediction:  [1.] true return:  0.05097737908363342
# n:  1155
# what are they? Index(['skewness_dxy', 'dist_top_band_copper', 'correlation_with_dxy'], dtype='object')
# 1165
# col 3
# Correct!!! ... prediction:  [1.] true return:  0.13966582715511322
# n:  1166
# what are they? Index(['skewness_dxy', 'dist_top_band_copper', 'correlation_with_dxy'], dtype='object')
# 1176
# col 5
# Correct!!! ... prediction:  [1.] true return:  0.12488467991352081
# n:  1177
# what are they? Index(['skewness_dxy', 'difference_from_mean_copper', 'correlation_with_dxy',
#        'lagged20_copper', 'lagged20_sp500'],
#       dtype='object')
# 1187
# col 4
# Correct!!! ... prediction:  [-1.] true return:  -0.04420073330402374
# n:  1188
# what are they? Index(['difference_from_mean_dxy', 'correlation_with_treasury',
#        'correlation_with_dxy', 'lagged20_sp500'],
#       dtype='object')
# 1198
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.09396342933177948
# n:  1199
# what are they? Index(['correlation_with_dxy', 'lagged20_sp500'], dtype='object')
# 1209
# col 0
# 1210
# col 0
# 1211
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.08466917276382446
# n:  1212
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 1222
# col 7
# Not Correct:( ... prediction:  [1.] true return:  -0.013787970878183842
# n:  1223
# what are they? Index(['skewness_sp500', 'momentum_20_50_dxy', '10dayvolume_price_sp500',
#        'correlation_with_treasury', 'correlation_with_dxy', 'lagged20_sp500',
#        'lagged20_dxy'],
#       dtype='object')
# 1233
# col 9
# Correct!!! ... prediction:  [-1.] true return:  -0.0028132840525358915
# n:  1234
# what are they? Index(['skewness_sp500', 'momentum_20_50_treasury', 'momentum_20_50_dxy',
#        '10dayvolume_price_sp500', 'correlation_with_treasury',
#        'correlation_with_dxy', 'correlation_with_dxy_times_returns',
#        'lagged20_sp500', 'lagged20_dxy'],
#       dtype='object')
# 1244
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.0339067243039608
# n:  1245
# what are they? Index(['correlation_with_dxy', 'lagged20_sp500'], dtype='object')
# 1255
# col 9
# Correct!!! ... prediction:  [1.] true return:  0.06626302003860474
# n:  1256
# what are they? Index(['momentum_20_50_copper', 'momentum_20_50_treasury',
#        'momentum_20_50_dxy', '10dayvolume_price_sp500',
#        'correlation_with_treasury', 'correlation_with_dxy',
#        'correlation_with_treasury_times_returns', 'lagged20_sp500',
#        'lagged20_dxy'],
#       dtype='object')
# 1266
# col 8
# Not Correct:( ... prediction:  [-1.] true return:  0.09245593845844269
# n:  1267
# what are they? Index(['skewness_sp500', 'momentum_20_50_treasury', 'dist_top_band_dxy',
#        'correlation_with_treasury', 'correlation_with_dxy',
#        'correlation_with_treasury_times_returns', 'lagged20_sp500',
#        'lagged20_dxy'],
#       dtype='object')
# 1277
# col 5
# Not Correct:( ... prediction:  [-1.] true return:  0.06835916638374329
# n:  1278
# what are they? Index(['momentum_20_50_treasury', 'correlation_with_dxy',
#        'correlation_with_treasury_times_returns', 'lagged20_sp500',
#        'lagged20_dxy'],
#       dtype='object')
# 1288
# col 0
# 1289
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.03967424854636192
# n:  1290
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 1300
# col 2
# Not Correct:( ... prediction:  [1.] true return:  -0.06284284591674805
# n:  1301
# what are they? Index(['correlation_with_dxy', 'lagged20_sp500'], dtype='object')
# 1311
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.05921578407287598
# n:  1312
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 1322
# col 1
# 1323
# col 0
# 1324
# col 0
# 1325
# col 0
# 1326
# col 1
# 1327
# col 0
# 1328
# col 1
# 1329
# col 2
# Not Correct:( ... prediction:  [-1.] true return:  0.015886586159467697
# n:  1330
# what are they? Index(['difference_from_mean_copper', 'correlation_with_dxy'], dtype='object')
# 1340
# col 5
# Correct!!! ... prediction:  [1.] true return:  0.04799208790063858
# n:  1341
# what are they? Index(['momentum_20_50_copper', 'difference_from_mean_copper',
#        'difference_from_mean_dxy', 'correlation_with_dxy', 'lagged20_sp500'],
#       dtype='object')
# 1351
# col 5
# Not Correct:( ... prediction:  [1.] true return:  -0.00352978496812284
# n:  1352
# what are they? Index(['momentum_20_50_copper', 'difference_from_mean_copper',
#        'difference_from_mean_dxy', 'correlation_with_dxy', 'lagged20_sp500'],
#       dtype='object')
# 1362
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.022453775629401207
# n:  1363
# what are they? Index(['difference_from_mean_copper'], dtype='object')
# 1373
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.024442220106720924
# n:  1374
# what are they? Index(['momentum_20_50_copper'], dtype='object')
# 1384
# col 1
# 1385
# col 0
# 1386
# col 1
# 1387
# col 0
# 1388
# col 0
# 1389
# col 1
# 1390
# col 2
# Correct!!! ... prediction:  [-1.] true return:  -0.1225707158446312
# n:  1391
# what are they? Index(['momentum_20_50_copper', 'difference_from_mean_copper'], dtype='object')
# 1401
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.18332543969154358
# n:  1402
# what are they? Index(['momentum_20_50_copper'], dtype='object')
# 1412
# col 0
# 1413
# col 0
# 1414
# col 1
# 1415
# col 0
# 1416
# col 0
# 1417
# col 0
# 1418
# col 0
# 1419
# col 0
# 1420
# col 1
# 1421
# col 0
# 1422
# col 0
# 1423
# col 1
# 1424
# col 0
# 1425
# col 0
# 1426
# col 0
# 1427
# col 0
# 1428
# col 1
# 1429
# col 0
# 1430
# col 0
# 1431
# col 0
# 1432
# col 0
# 1433
# col 1
# 1434
# col 1
# 1435
# col 1
# 1436
# col 0
# 1437
# col 0
# 1438
# col 1
# 1439
# col 1
# 1440
# col 1
# 1441
# col 1
# 1442
# col 0
# 1443
# col 1
# 1444
# col 0
# 1445
# col 0
# 1446
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.023105956614017487
# n:  1447
# what are they? Index(['difference_from_mean_copper'], dtype='object')
# 1457
# col 0
# 1458
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.05962499976158142
# n:  1459
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 1469
# col 0
# 1470
# col 0
# 1471
# col 0
# 1472
# col 1
# 1473
# col 1
# 1474
# col 1
# 1475
# col 1
# 1476
# col 0
# 1477
# col 2
# Correct!!! ... prediction:  [-1.] true return:  -0.11803361028432846
# n:  1478
# what are they? Index(['dist_top_band_dxy', 'correlation_with_dxy'], dtype='object')
# 1488
# col 0
# 1489
# col 0
# 1490
# col 2
# Not Correct:( ... prediction:  [-1.] true return:  0.043991200625896454
# n:  1491
# what are they? Index(['dist_top_band_dxy', 'correlation_with_dxy'], dtype='object')
# 1501
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.001883391523733735
# n:  1502
# what are they? Index(['momentum_20_50_sp500'], dtype='object')
# 1512
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.07838420569896698
# n:  1513
# what are they? Index(['VWAP_futures', 'volatility_copper', 'momentum_20_50_sp500'], dtype='object')
# 1523
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.0330740362405777
# n:  1524
# what are they? Index(['volatility_treasury'], dtype='object')
# 1534
# col 0
# 1535
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.0077359480783343315
# n:  1536
# what are they? Index(['volatility_copper'], dtype='object')
# 1546
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.0028185241390019655
# n:  1547
# what are they? Index(['VWAP_futures', 'volatility_copper'], dtype='object')
# 1557
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.037418436259031296
# n:  1558
# what are they? Index(['volatility_copper'], dtype='object')
# 1568
# col 0
# 1569
# col 0
# 1570
# col 0
# 1571
# col 1
# 1572
# col 0
# 1573
# col 1
# 1574
# col 0
# 1575
# col 0
# 1576
# col 0
# 1577
# col 1
# 1578
# col 0
# 1579
# col 0
# 1580
# col 0
# 1581
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.023931073024868965
# n:  1582
# what are they? Index(['VWAP_futures'], dtype='object')
# 1592
# col 0
# 1593
# col 0
# 1594
# col 0
# 1595
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.017387062311172485
# n:  1596
# what are they? Index(['volatility_copper'], dtype='object')
# 1606
# col 2
# Not Correct:( ... prediction:  [-1.] true return:  0.04057133197784424
# n:  1607
# what are they? Index(['volatility_copper', 'volatility_sp500'], dtype='object')
# 1617
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.05001276358962059
# n:  1618
# what are they? Index(['volatility_copper', 'volatility_sp500'], dtype='object')
# 1628
# col 0
# 1629
# col 0
# 1630
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.01852865144610405
# n:  1631
# what are they? Index(['volatility_sp500'], dtype='object')
# 1641
# col 1
# 1642
# col 1
# 1643
# col 0
# 1644
# col 0
# 1645
# col 1
# 1646
# col 0
# 1647
# col 1
# 1648
# col 0
# 1649
# col 0
# 1650
# col 1
# 1651
# col 1
# 1652
# col 0
# 1653
# col 0
# 1654
# col 0
# 1655
# col 0
# 1656
# col 0
# 1657
# col 0
# 1658
# col 0
# 1659
# col 0
# 1660
# col 0
# 1661
# col 1
# 1662
# col 0
# 1663
# col 1
# 1664
# col 0
# 1665
# col 1
# 1666
# col 0
# 1667
# col 0
# 1668
# col 0
# 1669
# col 1
# 1670
# col 0
# 1671
# col 0
# 1672
# col 1
# 1673
# col 1
# 1674
# col 0
# 1675
# col 0
# 1676
# col 0
# 1677
# col 1
# 1678
# col 0
# 1679
# col 0
# 1680
# col 0
# 1681
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.03889627382159233
# n:  1682
# what are they? Index(['%D_treasury'], dtype='object')
# 1692
# col 0
# 1693
# col 1
# 1694
# col 1
# 1695
# col 0
# 1696
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.01912612095475197
# n:  1697
# what are they? Index(['%D_treasury', 'volatility_sp500', 'correlation_with_treasury'], dtype='object')
# 1707
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.015454333275556564
# n:  1708
# what are they? Index(['correlation_with_treasury'], dtype='object')
# 1718
# col 4
# Correct!!! ... prediction:  [-1.] true return:  -0.06664866954088211
# n:  1719
# what are they? Index(['%D_treasury', 'volatility_sp500', 'volatility_dxy',
#        'correlation_with_treasury'],
#       dtype='object')
# 1729
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.043155964463949203
# n:  1730
# what are they? Index(['%D_treasury', 'correlation_with_treasury'], dtype='object')
# 1740
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.003538890276104212
# n:  1741
# what are they? Index(['%D_treasury', 'volatility_dxy', 'correlation_with_treasury'], dtype='object')
# 1751
# col 6
# Correct!!! ... prediction:  [1.] true return:  0.011910089291632175
# n:  1752
# what are they? Index(['%D_treasury', 'volatility_sp500', 'volatility_dxy',
#        'momentum_8_20_treasury', 'dist_bottom_band_copper',
#        'correlation_with_treasury'],
#       dtype='object')
# 1762
# col 4
# Correct!!! ... prediction:  [1.] true return:  0.06642629206180573
# n:  1763
# what are they? Index(['%D_treasury', 'volatility_sp500', 'volatility_dxy',
#        'correlation_with_treasury'],
#       dtype='object')
# 1773
# col 5
# Not Correct:( ... prediction:  [-1.] true return:  0.01715138740837574
# n:  1774
# what are they? Index(['%D_treasury', 'skewness_copper', 'volatility_sp500',
#        'volatility_treasury', 'correlation_with_treasury'],
#       dtype='object')
# 1784
# col 0
# 1785
# col 0
# 1786
# col 0
# 1787
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.07708504050970078
# n:  1788
# what are they? Index(['%D_treasury'], dtype='object')
# 1798
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.03753906488418579
# n:  1799
# what are they? Index(['volatility_dxy'], dtype='object')
# 1809
# col 0
# 1810
# col 0
# 1811
# col 0
# 1812
# col 0
# 1813
# col 5
# Not Correct:( ... prediction:  [1.] true return:  -0.07066702097654343
# n:  1814
# what are they? Index(['%D_treasury', 'skewness_sp500', 'volatility_copper', 'volatility_dxy',
#        'correlation_with_treasury'],
#       dtype='object')
# 1824
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.17879533767700195
# n:  1825
# what are they? Index(['volatility_dxy'], dtype='object')
# 1835
# col 1
# 1836
# col 1
# 1837
# col 0
# 1838
# col 1
# 1839
# col 1
# 1840
# col 1
# 1841
# col 1
# 1842
# col 7
# Correct!!! ... prediction:  [1.] true return:  0.06679972261190414
# n:  1843
# what are they? Index(['%D_treasury', 'skewness_copper', 'skewness_sp500', 'volatility_dxy',
#        'momentum_20_50_dxy', 'dist_to_bottom_copper',
#        'correlation_with_treasury'],
#       dtype='object')
# 1853
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.006536068394780159
# n:  1854
# what are they? Index(['volatility_dxy'], dtype='object')
# 1864
# col 0
# 1865
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.0324639230966568
# n:  1866
# what are they? Index(['skewness_treasury'], dtype='object')
# 1876
# col 0
# 1877
# col 1
# 1878
# col 1
# 1879
# col 0
# 1880
# col 0
# 1881
# col 0
# 1882
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.004601822234690189
# n:  1883
# what are they? Index(['skewness_copper'], dtype='object')
# 1893
# col 0
# 1894
# col 0
# 1895
# col 0
# 1896
# col 0
# 1897
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.06407096236944199
# n:  1898
# what are they? Index(['skewness_copper', 'skewness_sp500'], dtype='object')
# 1908
# col 0
# 1909
# col 0
# 1910
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.0034970170818269253
# n:  1911
# what are they? Index(['skewness_copper'], dtype='object')
# 1921
# col 2
# Correct!!! ... prediction:  [-1.] true return:  -0.04476049542427063
# n:  1922
# what are they? Index(['%D_treasury', 'difference_from_mean_treasury'], dtype='object')
# 1932
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.03379960358142853
# n:  1933
# what are they? Index(['%D_treasury', 'skewness_copper'], dtype='object')
# 1943
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.016704007983207703
# n:  1944
# what are they? Index(['%D_treasury', 'skewness_copper', 'difference_from_mean_treasury'], dtype='object')
# 1954
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.012414535507559776
# n:  1955
# what are they? Index(['%D_treasury'], dtype='object')
# 1965
# col 0
# 1966
# col 0
# 1967
# col 0
# 1968
# col 0
# 1969
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.023498298600316048
# n:  1970
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 1980
# col 0
# 1981
# col 1
# 1982
# col 1
# 1983
# col 0
# 1984
# col 0
# 1985
# col 0
# 1986
# col 0
# 1987
# col 1
# 1988
# col 0
# 1989
# col 0
# 1990
# col 0
# 1991
# col 0
# 1992
# col 1
# 1993
# col 1
# 1994
# col 3
# Correct!!! ... prediction:  [-1.] true return:  -0.02472536265850067
# n:  1995
# what are they? Index(['%D_treasury', 'difference_from_mean_treasury', 'correlation_with_dxy'], dtype='object')
# 2005
# col 0
# 2006
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.020551713183522224
# n:  2007
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 2017
# col 4
# Correct!!! ... prediction:  [1.] true return:  0.016079071909189224
# n:  2018
# what are they? Index(['%D_treasury', 'difference_from_mean_treasury', 'correlation_with_dxy',
#        'lagged20_copper'],
#       dtype='object')
# 2028
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.029073558747768402
# n:  2029
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 2039
# col 2
# Correct!!! ... prediction:  [-1.] true return:  -0.028297971934080124
# n:  2040
# what are they? Index(['correlation_with_dxy', 'lagged20_copper'], dtype='object')
# 2050
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.016785141080617905
# n:  2051
# what are they? Index(['correlation_with_dxy', 'lagged20_copper'], dtype='object')
# 2061
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.009287625551223755
# n:  2062
# what are they? Index(['correlation_with_treasury'], dtype='object')
# 2072
# col 1
# 2073
# col 0
# 2074
# col 1
# 2075
# col 1
# 2076
# col 1
# 2077
# col 0
# 2078
# col 0
# 2079
# col 0
# 2080
# col 0
# 2081
# col 1
# 2082
# col 1
# 2083
# col 1
# 2084
# col 1
# 2085
# col 1
# 2086
# col 0
# 2087
# col 1
# 2088
# col 1
# 2089
# col 0
# 2090
# col 0
# 2091
# col 1
# 2092
# col 0
# 2093
# col 1
# 2094
# col 0
# 2095
# col 0
# 2096
# col 1
# 2097
# col 0
# 2098
# col 1
# 2099
# col 0
# 2100
# col 0
# 2101
# col 1
# 2102
# col 1
# 2103
# col 0
# 2104
# col 1
# 2105
# col 0
# 2106
# col 0
# 2107
# col 0
# 2108
# col 0
# 2109
# col 0
# 2110
# col 1
# 2111
# col 0
# 2112
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.008505557663738728
# n:  2113
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 2123
# col 0
# 2124
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.01576998084783554
# n:  2125
# what are they? Index(['correlation_with_treasury'], dtype='object')
# 2135
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.021854452788829803
# n:  2136
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 2146
# col 1
# 2147
# col 1
# 2148
# col 0
# 2149
# col 1
# 2150
# col 0
# 2151
# col 1
# 2152
# col 1
# 2153
# col 0
# 2154
# col 0
# 2155
# col 0
# 2156
# col 0
# 2157
# col 0
# 2158
# col 0
# 2159
# col 0
# 2160
# col 11
# Correct!!! ... prediction:  [-1.] true return:  -0.014090502634644508
# n:  2161
# what are they? Index(['%D_3daychangetreasury', 'dist_to_top_copper',
#        '10dayvolume_price_sp500', 'dist_top_band_copper',
#        'dist_bottom_band_dxy', 'difference_from_mean_treasury',
#        'correlation_with_treasury', 'correlation_with_dxy', 'lagged5_sp500',
#        'lagged20_copper', 'lagged20_sp500'],
#       dtype='object')
# 2171
# col 8
# Correct!!! ... prediction:  [1.] true return:  0.0274678785353899
# n:  2172
# what are they? Index(['momentum_8_20_treasury', 'dist_to_top_copper', 'dist_top_band_copper',
#        'dist_bottom_band_dxy', 'difference_from_mean_treasury',
#        'correlation_with_treasury', 'correlation_with_dxy', 'lagged20_copper'],
#       dtype='object')
# 2182
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.022889217361807823
# n:  2183
# what are they? Index(['correlation_with_dxy'], dtype='object')
# 2193
# col 0
# 2194
# col 1
# 2195
# col 1
# 2196
# col 0
# 2197
# col 1
# 2198
# col 1
# 2199
# col 1
# 2200
# col 1
# 2201
# col 0
# 2202
# col 1
# 2203
# col 1
# 2204
# col 0
# 2205
# col 1
# 2206
# col 0
# 2207
# col 1
# 2208
# col 0
# 2209
# col 0
# 2210
# col 1
# 2211
# col 0
# 2212
# col 0
# 2213
# col 0
# 2214
# col 0
# 2215
# col 1
# 2216
# col 1
# 2217
# col 0
# 2218
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.00019648176385089755
# n:  2219
# what are they? Index(['correlation_with_treasury'], dtype='object')
# 2229
# col 1
# 2230
# col 1
# 2231
# col 0
# 2232
# col 1
# 2233
# col 0
# 2234
# col 1
# 2235
# col 1
# 2236
# col 1
# 2237
# col 1
# 2238
# col 1
# 2239
# col 1
# 2240
# col 1
# 2241
# col 0
# 2242
# col 0
# 2243
# col 0
# 2244
# col 1
# 2245
# col 1
# 2246
# col 0
# 2247
# col 0
# 2248
# col 0
# 2249
# col 0
# 2250
# col 0
# 2251
# col 0
# 2252
# col 0
# 2253
# col 0
# 2254
# col 1
# 2255
# col 0
# 2256
# col 0
# 2257
# col 0
# 2258
# col 0
# 2259
# col 0
# 2260
# col 1
# 2261
# col 1
# 2262
# col 1
# 2263
# col 1
# 2264
# col 1
# 2265
# col 1
# 2266
# col 1
# 2267
# col 1
# 2268
# col 1
# 2269
# col 0
# 2270
# col 1
# 2271
# col 0
# 2272
# col 0
# 2273
# col 0
# 2274
# col 0
# 2275
# col 1
# 2276
# col 0
# 2277
# col 0
# 2278
# col 1
# 2279
# col 0
# 2280
# col 2
# Not Correct:( ... prediction:  [-1.] true return:  0.027695562690496445
# n:  2281
# what are they? Index(['volatility_sp500', 'correlation_with_treasury'], dtype='object')
# 2291
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.018401317298412323
# n:  2292
# what are they? Index(['volatility_sp500'], dtype='object')
# 2302
# col 1
# 2303
# col 1
# 2304
# col 1
# 2305
# col 0
# 2306
# col 0
# 2307
# col 0
# 2308
# col 0
# 2309
# col 0
# 2310
# col 1
# 2311
# col 0
# 2312
# col 0
# 2313
# col 1
# 2314
# col 1
# 2315
# col 0
# 2316
# col 1
# 2317
# col 0
# 2318
# col 0
# 2319
# col 1
# 2320
# col 0
# 2321
# col 0
# 2322
# col 1
# 2323
# col 1
# 2324
# col 0
# 2325
# col 0
# 2326
# col 0
# 2327
# col 0
# 2328
# col 0
# 2329
# col 0
# 2330
# col 0
# 2331
# col 0
# 2332
# col 0
# 2333
# col 0
# 2334
# col 1
# 2335
# col 1
# 2336
# col 1
# 2337
# col 0
# 2338
# col 1
# 2339
# col 1
# 2340
# col 0
# 2341
# col 0
# 2342
# col 1
# 2343
# col 0
# 2344
# col 1
# 2345
# col 1
# 2346
# col 1
# 2347
# col 0
# 2348
# col 0
# 2349
# col 1
# 2350
# col 0
# 2351
# col 0
# 2352
# col 1
# 2353
# col 0
# 2354
# col 1
# 2355
# col 1
# 2356
# col 1
# 2357
# col 0
# 2358
# col 1
# 2359
# col 0
# 2360
# col 0
# 2361
# col 0
# 2362
# col 0
# 2363
# col 0
# 2364
# col 1
# 2365
# col 1
# 2366
# col 1
# 2367
# col 1
# 2368
# col 0
# 2369
# col 0
# 2370
# col 1
# 2371
# col 1
# 2372
# col 0
# 2373
# col 0
# 2374
# col 1
# 2375
# col 0
# 2376
# col 1
# 2377
# col 0
# 2378
# col 0
# 2379
# col 0
# 2380
# col 1
# 2381
# col 0
# 2382
# col 0
# 2383
# col 0
# 2384
# col 1
# 2385
# col 1
# 2386
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.007149352692067623
# n:  2387
# what are they? Index(['volatility_sp500', 'momentum_8_20_dxy',
#        'correlation_with_dxy_times_returns'],
#       dtype='object')
# 2397
# col 0
# 2398
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.04547348991036415
# n:  2399
# what are they? Index(['volatility_sp500'], dtype='object')
# 2409
# col 1
# 2410
# col 0
# 2411
# col 1
# 2412
# col 1
# 2413
# col 0
# 2414
# col 0
# 2415
# col 0
# 2416
# col 1
# 2417
# col 1
# 2418
# col 1
# 2419
# col 0
# 2420
# col 1
# 2421
# col 1
# 2422
# col 1
# 2423
# col 0
# 2424
# col 0
# 2425
# col 0
# 2426
# col 0
# 2427
# col 1
# 2428
# col 1
# 2429
# col 1
# 2430
# col 1
# 2431
# col 0
# 2432
# col 1
# 2433
# col 0
# 2434
# col 1
# 2435
# col 0
# 2436
# col 1
# 2437
# col 0
# 2438
# col 0
# 2439
# col 0
# 2440
# col 0
# 2441
# col 0
# 2442
# col 0
# 2443
# col 0
# 2444
# col 0
# 2445
# col 0
# 2446
# col 0
# 2447
# col 0
# 2448
# col 0
# 2449
# col 1
# 2450
# col 1
# 2451
# col 0
# 2452
# col 1
# 2453
# col 0
# 2454
# col 0
# 2455
# col 0
# 2456
# col 1
# 2457
# col 0
# 2458
# col 1
# 2459
# col 0
# 2460
# col 0
# 2461
# col 0
# 2462
# col 1
# 2463
# col 0
# 2464
# col 0
# 2465
# col 1
# 2466
# col 0
# 2467
# col 0
# 2468
# col 1
# 2469
# col 0
# 2470
# col 0
# 2471
# col 1
# 2472
# col 1
# 2473
# col 1
# 2474
# col 0
# 2475
# col 0
# 2476
# col 1
# 2477
# col 3
# Not Correct:( ... prediction:  [-1.] true return:  0.031112955883145332
# n:  2478
# what are they? Index(['skewness_copper', 'volatility_sp500', 'momentum_20_50_copper'], dtype='object')
# 2488
# col 3
# Correct!!! ... prediction:  [1.] true return:  0.0007501167710870504
# n:  2489
# what are they? Index(['skewness_copper', 'volatility_sp500', 'momentum_20_50_copper'], dtype='object')
# 2499
# col 2
# Correct!!! ... prediction:  [-1.] true return:  -0.0014222720637917519
# n:  2500
# what are they? Index(['volatility_sp500', 'momentum_20_50_copper'], dtype='object')
# 2510
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.02486761473119259
# n:  2511
# what are they? Index(['volatility_sp500'], dtype='object')
# 2521
# col 0
# 2522
# col 1
# 2523
# col 0
# 2524
# col 1
# 2525
# col 1
# 2526
# col 0
# 2527
# col 1
# 2528
# col 0
# 2529
# col 1
# 2530
# col 0
# 2531
# col 0
# 2532
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.03314300253987312
# n:  2533
# what are they? Index(['dist_top_band_copper'], dtype='object')
# 2543
# col 1
# 2544
# col 1
# 2545
# col 1
# 2546
# col 0
# 2547
# col 0
# 2548
# col 0
# 2549
# col 0
# 2550
# col 1
# 2551
# col 0
# 2552
# col 0
# 2553
# col 0
# 2554
# col 0
# 2555
# col 0
# 2556
# col 1
# 2557
# col 0
# 2558
# col 0
# 2559
# col 0
# 2560
# col 0
# 2561
# col 1
# 2562
# col 0
# 2563
# col 1
# 2564
# col 0
# 2565
# col 1
# 2566
# col 1
# 2567
# col 0
# 2568
# col 0
# 2569
# col 0
# 2570
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.040905989706516266
# n:  2571
# what are they? Index(['skewness_copper'], dtype='object')
# 2581
# col 0
# 2582
# col 0
# 2583
# col 0
# 2584
# col 0
# 2585
# col 1
# 2586
# col 1
# 2587
# col 0
# 2588
# col 0
# 2589
# col 0
# 2590
# col 1
# 2591
# col 0
# 2592
# col 1
# 2593
# col 0
# 2594
# col 1
# 2595
# col 0
# 2596
# col 1
# 2597
# col 0
# 2598
# col 1
# 2599
# col 1
# 2600
# col 0
# 2601
# col 0
# 2602
# col 0
# 2603
# col 0
# 2604
# col 0
# 2605
# col 0
# 2606
# col 0
# 2607
# col 0
# 2608
# col 0
# 2609
# col 0
# 2610
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.005074377171695232
# n:  2611
# what are they? Index(['dist_top_band_copper'], dtype='object')
# 2621
# col 0
# 2622
# col 0
# 2623
# col 1
# 2624
# col 1
# 2625
# col 1
# 2626
# col 1
# 2627
# col 0
# 2628
# col 0
# 2629
# col 1
# 2630
# col 0
# 2631
# col 0
# 2632
# col 1
# 2633
# col 1
# 2634
# col 0
# 2635
# col 0
# 2636
# col 0
# 2637
# col 0
# 2638
# col 0
# 2639
# col 2
# Correct!!! ... prediction:  [1.] true return:  0.008160953409969807
# n:  2640
# what are they? Index(['dist_top_band_copper', 'difference_from_mean_copper'], dtype='object')
# 2650
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.028575800359249115
# n:  2651
# what are they? Index(['difference_from_mean_copper'], dtype='object')
# 2661
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.006513705011457205
# n:  2662
# what are they? Index(['skewness_copper'], dtype='object')
# 2672
# col 0
# 2673
# col 2
# Not Correct:( ... prediction:  [1.] true return:  -0.028414728119969368
# n:  2674
# what are they? Index(['skewness_treasury', 'dist_top_band_copper'], dtype='object')
# 2684
# col 4
# Correct!!! ... prediction:  [-1.] true return:  -0.055188801139593124
# n:  2685
# what are they? Index(['%D_dxy', 'skewness_treasury', 'volatility_copper',
#        'dist_top_band_copper'],
#       dtype='object')
# 2695
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.01056667696684599
# n:  2696
# what are they? Index(['volatility_copper'], dtype='object')
# 2706
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.007240565959364176
# n:  2707
# what are they? Index(['skewness_treasury'], dtype='object')
# 2717
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.0365828312933445
# n:  2718
# what are they? Index(['skewness_copper'], dtype='object')
# 2728
# col 0
# 2729
# col 0
# 2730
# col 0
# 2731
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.034874316304922104
# n:  2732
# what are they? Index(['skewness_treasury'], dtype='object')
# 2742
# col 0
# 2743
# col 1
# 2744
# col 0
# 2745
# col 1
# 2746
# col 0
# 2747
# col 0
# 2748
# col 1
# 2749
# col 1
# 2750
# col 0
# 2751
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.0029784180223941803
# n:  2752
# what are they? Index(['%D_dxy'], dtype='object')
# 2762
# col 0
# 2763
# col 1
# 2764
# col 0
# 2765
# col 0
# 2766
# col 1
# 2767
# col 1
# 2768
# col 1
# 2769
# col 1
# 2770
# col 1
# 2771
# col 2
# Correct!!! ... prediction:  [-1.] true return:  -0.035682521760463715
# n:  2772
# what are they? Index(['%D_dxy', 'skewness_treasury'], dtype='object')
# 2782
# col 0
# 2783
# col 0
# 2784
# col 0
# 2785
# col 0
# 2786
# col 0
# 2787
# col 0
# 2788
# col 0
# 2789
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.04416540637612343
# n:  2790
# what are they? Index(['%D_dxy'], dtype='object')
# 2800
# col 1
# Not Correct:( ... prediction:  [-1.] true return:  0.006428036373108625
# n:  2801
# what are they? Index(['volatility_copper'], dtype='object')
# 2811
# col 0
# 2812
# col 0
# 2813
# col 1
# 2814
# col 0
# 2815
# col 0
# 2816
# col 0
# 2817
# col 1
# 2818
# col 0
# 2819
# col 0
# 2820
# col 0
# 2821
# col 0
# 2822
# col 1
# 2823
# col 1
# 2824
# col 0
# 2825
# col 0
# 2826
# col 1
# 2827
# col 0
# 2828
# col 1
# 2829
# col 1
# 2830
# col 0
# 2831
# col 1
# 2832
# col 1
# 2833
# col 0
# 2834
# col 1
# 2835
# col 0
# 2836
# col 1
# 2837
# col 0
# 2838
# col 0
# 2839
# col 0
# 2840
# col 1
# 2841
# col 1
# 2842
# col 0
# 2843
# col 0
# 2844
# col 0
# 2845
# col 0
# 2846
# col 1
# 2847
# col 1
# 2848
# col 0
# 2849
# col 1
# 2850
# col 0
# 2851
# col 0
# 2852
# col 0
# 2853
# col 0
# 2854
# col 0
# 2855
# col 0
# 2856
# col 1
# 2857
# col 0
# 2858
# col 0
# 2859
# col 1
# 2860
# col 0
# 2861
# col 1
# 2862
# col 56
# Correct!!! ... prediction:  [-1.] true return:  -0.06368935108184814
# n:  2863
# what are they? Index(['VWAP_futures', 'volume_price', '%D_copper', '%D_3daychangecopper',
#        '%D_3daychangesp500', '%D_treasury', '%D_3daychangetreasury', '%D_dxy',
#        '%D_3daychangedxy', 'skewness_copper', 'skewness_sp500', 'skewness_dxy',
#        'volatility_copper', 'volatility_sp500', 'volatility_treasury',
#        'volatility_dxy', 'momentum_20_50_copper', 'momentum_8_20_copper',
#        'momentum_20_50_sp500', 'momentum_8_20_sp500',
#        'momentum_20_50_treasury', 'momentum_8_20_treasury',
#        'momentum_8_20_dxy', 'dist_to_bottom_copper', 'dist_to_top_copper',
#        'dist_to_bottom_sp500', 'dist_to_top_sp500', 'dist_to_bottom_dxy',
#        'dist_to_top_dxy', 'rsi_copper', 'rsi_change_copper', 'macd_rsi_copper',
#        '10dayvolume_price_copper', '10dayvolume_price_sp500',
#        'dist_top_band_copper', 'dist_bottom_band_copper',
#        'dist_top_band_treasury', 'dist_top_band_dxy', 'dist_bottom_band_dxy',
#        'difference_from_mean_copper', 'difference_from_mean_sp500',
#        'difference_from_mean_treasury', 'difference_from_mean_dxy',
#        'correlation_with_sp500', 'correlation_with_treasury',
#        'correlation_with_dxy', 'correlation_with_sp500_times_returns',
#        'correlation_with_treasury_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged5_copper', 'lagged5_sp500',
#        'lagged5_treasury', 'lagged5_dxy', 'lagged20_copper',
#        'lagged20_treasury', 'lagged20_dxy'],
#       dtype='object')
# 2873
# col 0
# 2874
# col 1
# Correct!!! ... prediction:  [1.] true return:  0.027393130585551262
# n:  2875
# what are they? Index(['volatility_copper'], dtype='object')
# 2885
# col 0
# 2886
# col 0
# 2887
# col 1
# Correct!!! ... prediction:  [-1.] true return:  -0.01439386885613203
# n:  2888
# what are they? Index(['correlation_with_sp500'], dtype='object')
# 2898
# col 1
# 2899
# col 0
# 2900
# col 0
# 2901
# col 1
# 2902
# col 1
# 2903
# col 1
# 2904
# col 30
# Correct!!! ... prediction:  [-1.] true return:  -0.07850683480501175
# n:  2905
# what are they? Index(['%D_treasury', '%D_dxy', 'skewness_sp500', 'skewness_dxy',
#        'volatility_copper', 'volatility_dxy', 'momentum_20_50_copper',
#        'momentum_8_20_copper', 'momentum_20_50_sp500', 'momentum_8_20_sp500',
#        'momentum_8_20_treasury', 'momentum_20_50_dxy', 'momentum_8_20_dxy',
#        'dist_to_bottom_copper', 'dist_to_top_copper', 'dist_to_bottom_sp500',
#        'dist_to_top_sp500', 'dist_to_bottom_dxy', '10dayvolume_price_copper',
#        '10dayvolume_price_sp500', 'dist_top_band_treasury',
#        'dist_top_band_dxy', 'difference_from_mean_treasury',
#        'correlation_with_sp500', 'correlation_with_treasury',
#        'correlation_with_sp500_times_returns',
#        'correlation_with_dxy_times_returns', 'lagged20_copper',
#        'lagged20_sp500', 'lagged20_treasury'],
#       dtype='object')
# 2915
# col 0
# 2916
# col 0
# 2917
# col 0
# 2918
# col 1
# Not Correct:( ... prediction:  [1.] true return:  -0.01446620561182499
# n:  2919
# what are they? Index(['correlation_with_sp500'], dtype='object')
# 2929
# col 6
# Not Correct:( ... prediction:  [-1.] true return:  0.02798861637711525
# n:  2930
# what are they? Index(['%D_dxy', 'skewness_sp500', 'volatility_copper',
#        'momentum_20_50_copper', 'momentum_20_50_dxy',
#        'correlation_with_sp500'],
#       dtype='object')
# 2940
# col 2
# Not Correct:( ... prediction:  [-1.] true return:  0.0
# n:  2941
# what are they? Index(['volatility_copper', 'correlation_with_sp500'], dtype='object')

# %%
true_return_ = np.cumprod(1+pd.Series(true_return))
true_return_.plot()

# %%
payout = np.zeros(shape=(len(original_signals),1))
for i in range(len(real_returns)):
    #print(i)
    if original_signals[i] != 0:
        signals = []
        for k in range((10)):
            signals.append(real_returns[i+2+k]*original_signals[i])
            cum_signal_return = np.cumprod(1+pd.Series(signals))

            if ((1-cum_signal_return.iloc[-1]) < 0.01) and ((1-cum_signal_return.iloc[-1]) > -0.07):
                payout[i+1+k] = original_signals[i]
            else:
                break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-171-f6a104d49dc6> in <module>
#       5         signals = []
#       6         for k in range((10)):
# ----> 7             signals.append(real_returns[i+2+k]*original_signals[i])
#       8             cum_signal_return = np.cumprod(1+pd.Series(signals))
#       9
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     877
#     878         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 879             return self._values[key]
#     880
#     881         elif key_is_scalar:
#
# IndexError: index 3343 is out of bounds for axis 0 with size 3342

# %%
final_signals = np.zeros(shape=(len(original_signals),1))

for i in range(len(copper)):
    if original_signals[i] != 0:
        final_signals[i] = original_signals[i]
    if payout[i] != 0:
        final_signals[i] = payout[i]

# %%
final_returns = np.zeros(shape=(len(original_signals),1))
for i in range(len(final_returns)-2):
    final_returns[i+2] = final_signals[i][0]*real_returns[i+2]

# %%
final_returns_=[]
for i in final_returns:
    final_returns_.append(float(i))
    
np.cumprod(1+pd.Series(final_returns_[window_size:n+window_size])).plot()

# %%
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 80

final_returns__ = np.cumprod(1+pd.Series(final_returns_[window_size:n+window_size]))
final_returns__.index = real_returns[window_size:].index
real_returns__ = np.cumprod(1+real_returns[window_size:])
plt.plot(real_returns__, label = 'Copper Return')
plt.plot(final_returns__, label= 'Strategy Return')
plt.legend(loc="upper left", fontsize =12)
plt.title('Strategy Performance')
# Out:
# Text(0.5, 1.0, 'Strategy Performance')

# %%
max_depth_dict = dict()
min_samples_leaf_dict = dict()
min_samples_split_dict = dict()
n_estimators_dict = dict()
    

for i in max_depth:

    if i in max_depth_dict.keys():
        max_depth_dict[i] += 1
    else:
        max_depth_dict[i] = 1

for i in min_samples_leaf:
    if i in min_samples_leaf_dict.keys():
        min_samples_leaf_dict[i] += 1
    else:
        min_samples_leaf_dict[i] = 1
    
for i in min_samples_split:
    if i in min_samples_split_dict.keys():
        min_samples_split_dict[i] += 1
    else:
        min_samples_split_dict[i] = 1
        
for i in n_estimators:
    if i in n_estimators_dict.keys():
        n_estimators_dict[i] += 1
    else:
        n_estimators_dict[i] = 1
